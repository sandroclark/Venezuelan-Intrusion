# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import scale
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
venezuela_users = pd.read_csv('/Users/alessandro/Downloads/venezuela_201906_1_users_csv_hashed.csv')

# %%
venezuela_users.head(100)
# Out:
#                                           userid  \
# 0                             778257194076831744
# 1     UaoSsTUDoR7SIA0dvPLYLRt70LG0VUSS3AcrE9FUE=
# 2                             801485278858854401
# 3                             881675624401833984
# 4                             768237282562310144
# 5                             801200139155214336
# 6                             828668571765133317
# 7                             801555575687495681
# 8    944Ry+vVZhaSln1T9ctgWQ6N5g45ReoWpWSXfrgKFc=
# 9                             896121971989262336
# 10                            933477319615877120
# 11                            801463213833547776
# 12                            751635009052827648
# 13                            801609388779769857
# 14                            751630413769113601
# 15                            801442896041873409
# 16                            933480574685270017
# 17                            892133369965944833
# 18                            772513370599747585
# 19  MUqZv6hxFW92V7lxJyf35c8BU8esdxS6IoV1QGiwwtQ=
# 20                            801569072618029056
# 21                            741112500356276225
# 22                            769380097359024128
# 23  TDgi60XrT+ylS+rVJEMhb4Y2qzW2HnZmlijAyHNqavc=
# 24  55DeTN4VJIeKfM9Atr0sSTLomZbJyUWuBNdDK2an1nE=
# 25                                     568620329
# 26                            741092772233482241
# 27   EAMY+7SRc0r53i1vfKV4UvVAc+DAI4rtEpUjFSbwbQ=
# 28                            801221525718335488
# 29                            862552763414323201
# 30                            761401522798333952
# 31                            801544458777063424
# 32                            945770142297939968
#
#                                user_display_name  \
# 0                              AmericaForTrump🇺🇸
# 1     UaoSsTUDoR7SIA0dvPLYLRt70LG0VUSS3AcrE9FUE=
# 2                            Evelyn Reporter👩🏻‍💻
# 3                                  TRUMP TRAIN🚂💨
# 4                                  #TrumpNews 🇺🇸
# 5                          TrumpservativeNews 🇺🇸
# 6                                  TRUMP TRAIN 🚂
# 7                           ▶ Trump Daily News 📰
# 8    944Ry+vVZhaSln1T9ctgWQ6N5g45ReoWpWSXfrgKFc=
# 9                             Emma🌺| Reporter👩‍💻
# 10                             TRUMP MEDIA NEWS⏺
# 11                            ▶ TRUMP NEWS DAILY
# 12                             Caroline Walker 🌸
# 13                                 Olivia Allen🚂
# 14                                  Aria Wilson🚂
# 15                               Samantha Clark💕
# 16                                Breaking News🔥
# 17                                 Lauren4Trump🍒
# 18                                Sophia Evans💗🌴
# 19  MUqZv6hxFW92V7lxJyf35c8BU8esdxS6IoV1QGiwwtQ=
# 20                                Anna🇲 🇦 🇬 🇦 🇺🇸
# 21                               Sophia Miller 💙
# 22                           TRUMPTRAIN🚂FakeNews
# 23  TDgi60XrT+ylS+rVJEMhb4Y2qzW2HnZmlijAyHNqavc=
# 24  55DeTN4VJIeKfM9Atr0sSTLomZbJyUWuBNdDK2an1nE=
# 25                             Noticias Viral TV
# 26                               Lauren Jones 🇺🇸
# 27   EAMY+7SRc0r53i1vfKV4UvVAc+DAI4rtEpUjFSbwbQ=
# 28                               🌹Alyssa Nelson🐸
# 29                               Caroline Walker
# 30                                  Abby Martin✨
# 31                               Lauren Jones 🇺🇸
# 32                           Citizens For Trump🌎
#
#                                 user_screen_name user_reported_location  \
# 0                                 America4Trump_         Washington, DC
# 1     UaoSsTUDoR7SIA0dvPLYLRt70LG0VUSS3AcrE9FUE=         Washington, DC
# 2                                 EvelynWhiteGOP                    NaN
# 3                                   DTrumpTrain_                    NaN
# 4                                 GODBLESSAMERIC         Washington, DC
# 5                                     TrumpNewsz                    NaN
# 6                                  TRUMPTRAIN_17             Texas, USA
# 7                                TrumpDailyNewss                    NaN
# 8    944Ry+vVZhaSln1T9ctgWQ6N5g45ReoWpWSXfrgKFc=     Caracas, Venezuela
# 9                                   EmmaTurnerBN                    NaN
# 10                                   _trumpnews_                    NaN
# 11                               TrumpNewsDaily_                    NaN
# 12                               CarolineWalkerB        Nueva York, USA
# 13                                  OliviaAllenC             Texas, USA
# 14                                 AriaWilsonGOP           New York, NY
# 15                                SamanthaClarkH             Texas, USA
# 16                               BreakingNewsDJT                    NaN
# 17                                 Laureen4Trump                    NaN
# 18                                  Sophia4Trump           Florida, USA
# 19  MUqZv6hxFW92V7lxJyf35c8BU8esdxS6IoV1QGiwwtQ=                    NaN
# 20                               AnnabelleBakerF           Florida, USA
# 21                                 SophiaMillerC        Nueva York, USA
# 22                               TrumpTrainNewss        Nueva York, USA
# 23  TDgi60XrT+ylS+rVJEMhb4Y2qzW2HnZmlijAyHNqavc=         Washington, DC
# 24  55DeTN4VJIeKfM9Atr0sSTLomZbJyUWuBNdDK2an1nE=                    NaN
# 25                               NoticiasViralTV                    NaN
# 26                                LaurenJonesGOP        Nueva York, USA
# 27   EAMY+7SRc0r53i1vfKV4UvVAc+DAI4rtEpUjFSbwbQ=             Texas, USA
# 28                                 AlyssaNelsonR                    NaN
# 29                                   CarolineWB_                    NaN
# 30                                   AbbyMartinM         Washington, DC
# 31                               LaurenJonesGOP_        Nueva York, USA
# 32                               Citizens4Trump_                    NaN
#
#                              user_profile_description  \
# 0   President Trump is a warrior giving a voice to...
# 1   Breaking News as it happens on everything Dona...
# 2   Reporter👩🏻‍💻,Animal lover🐶, 100% Support @real...
# 3   The voice of the Twitter community for Donald ...
# 4   Daily political news. #TrumpPence16 #GodBlessA...
# 5   Support and News for @realDonaldTrump 45th Pre...
# 6   Lets help @realDonaldTrump Make America Great ...
# 7   Get ready for All Trump All Day and all Night....
# 8   21│Farmacéutico en formación, UCV.            ...
# 9   YUGE Trump Supporter since the day Trump annou...
# 10  ONLY Trump News articles 24/7 throughout his h...
# 11  If you support Donald J. Trump, FOLLOW ME! New...
# 12  I am a Trump Supporter. You are allowed to voi...
# 13  ❤️ This is my first year of paying attention t...
# 14  I LOVE AMERICA I SUPPORT OUR VETS AND TROOPS L...
# 15  I'm a Trump supporter all the way to the WH. A...
# 16  Twitter's most comprehensive up-to-date news c...
# 17  100% Support @realDonaldTrump✨ 2020 Vision for...
# 18  100% Support @realDonaldTrump✨ 2020 Vision for...
# 19  Proudly followed by @realDonaldTrump 😎🎉💥 Just ...
# 20  Model, singer, socialite, fitness chick, cosme...
# 21                  Hillary is my choice! #NeverTrump
# 22  🇺🇸◽️A◽️M◽️E◽️R◽️I◽️C◽️A◽️🇺🇸◽️F◽️I◽️R◽️S◽️T◽ #M...
# 23  Women who support @realDonaldTrump & #MAGA age...
# 24  Entusiasta de #BTC & #AltCoins 💰 Enthusiast of...
# 25                                                NaN
# 26  Trump President 2016! Melania First Lady 2016!...
# 27  My Website is Updated Daily: Interviews & Rall...
# 28  Beer fanatic. Prone to fits of apathy. Food lo...
# 29                                                NaN
# 30  🇺🇸TRUMP OURS PRESIDENT!!🇺🇸🇺🇸 Dream highly❤️!#M...
# 31  Trump President 2016! Melania First Lady 2016!...
# 32  FAN ACCOUNT - The American citizens' grassroot...
#
#            user_profile_url  follower_count  following_count  \
# 0   https://t.co/XLyfrLF834           13184            10245
# 1   https://t.co/ZkpEZdjz6R            3716             4690
# 2   https://t.co/vC8RybJYHo           61537            57791
# 3   https://t.co/vC8RybJYHo           47083            43254
# 4   https://t.co/XLyfrLF834           15246            11249
# 5   https://t.co/vC8RybJYHo           64717            58804
# 6   https://t.co/ZkpEZdjz6R            5059             4718
# 7   https://t.co/vC8RybJYHo           57618            52827
# 8    http://t.co/oF3sm1zp5s            1357              224
# 9   https://t.co/vC8RybJYHo           34770            32618
# 10                      NaN            8895             8571
# 11  https://t.co/vC8RybJYHo           54778            50504
# 12  https://t.co/XLyfrLWJrE           23494            17352
# 13  https://t.co/XLyfrLF834            9828             8061
# 14  https://t.co/XLyfrLF834           24198            18392
# 15  https://t.co/XLyfrLF834           14036            10552
# 16                      NaN            9032             8970
# 17  https://t.co/vC8RybJYHo           40710            37628
# 18  https://t.co/XLyfrLF834           19806            15725
# 19  https://t.co/ZkpEZdjz6R            4848             4551
# 20  https://t.co/XLyfrLF834            9980             7564
# 21                      NaN            5589             5173
# 22  https://t.co/XLyfrLF834           20661            17298
# 23                      NaN            1561             2629
# 24                      NaN             146             1267
# 25                      NaN           44020             1928
# 26  https://t.co/ZkpEZdjz6R           19865            18275
# 27  https://t.co/ZkpEZdjz6R            4045             4048
# 28  https://t.co/XLyfrLF834           10669             8334
# 29                      NaN               0                6
# 30  https://t.co/XLyfrLF834           20176            15797
# 31  https://t.co/XLyfrLF834           17055            13632
# 32                      NaN            7366             8914
#
#    account_creation_date account_language
# 0             2016-09-20               es
# 1             2017-02-05               es
# 2             2016-11-23               es
# 3             2017-07-03               es
# 4             2016-08-24               es
# 5             2016-11-22               es
# 6             2017-02-06               es
# 7             2016-11-23               es
# 8             2012-04-25               es
# 9             2017-08-11               es
# 10            2017-11-22               es
# 11            2016-11-23               es
# 12            2016-07-09               es
# 13            2016-11-24               es
# 14            2016-07-09               es
# 15            2016-11-23               es
# 16            2017-11-22               es
# 17            2017-07-31               es
# 18            2016-09-04               es
# 19            2017-02-06               es
# 20            2016-11-23               es
# 21            2016-06-10               es
# 22            2016-08-27               es
# 23            2017-12-26               es
# 24            2018-01-09               es
# 25            2012-05-01               es
# 26            2016-06-10               es
# 27            2017-02-06               es
# 28            2016-11-23               es
# 29            2017-05-11               es
# 30            2016-08-05               es
# 31            2016-11-23               es
# 32            2017-12-26               es

# %%
venezuela_users.user_screen_name.nunique()
# Out:
# 33

# %%
venezuela_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 10 columns):
# userid                      33 non-null object
# user_display_name           33 non-null object
# user_screen_name            33 non-null object
# user_reported_location      18 non-null object
# user_profile_description    31 non-null object
# user_profile_url            25 non-null object
# follower_count              33 non-null int64
# following_count             33 non-null int64
# account_creation_date       33 non-null object
# account_language            33 non-null object
# dtypes: int64(2), object(8)
# memory usage: 2.7+ KB

# %%
venezuela_users.follower_count.sort_values()
# Out:
# 29        0
# 24      146
# 8      1357
# 23     1561
# 1      3716
# 27     4045
# 19     4848
# 6      5059
# 21     5589
# 32     7366
# 10     8895
# 16     9032
# 13     9828
# 20     9980
# 28    10669
# 0     13184
# 15    14036
# 4     15246
# 31    17055
# 18    19806
# 26    19865
# 30    20176
# 22    20661
# 12    23494
# 14    24198
# 9     34770
# 17    40710
# 25    44020
# 3     47083
# 11    54778
# 7     57618
# 2     61537
# 5     64717
# Name: follower_count, dtype: int64

# %%
venezuela_users.columns
# Out:
# Index(['userid', 'user_display_name', 'user_screen_name',
#        'user_reported_location', 'user_profile_description',
#        'user_profile_url', 'follower_count', 'following_count',
#        'account_creation_date', 'account_language'],
#       dtype='object')

# %%
venezuela_users.user_display_name.values
# Out:
# array(['AmericaForTrump🇺🇸', 'UaoSsTUDoR7SIA0dvPLYLRt70LG0VUSS3AcrE9FUE=',
#        'Evelyn Reporter👩🏻\u200d💻', 'TRUMP TRAIN🚂💨', '#TrumpNews 🇺🇸',
#        'TrumpservativeNews 🇺🇸', 'TRUMP TRAIN 🚂', '▶ Trump Daily News 📰',
#        '944Ry+vVZhaSln1T9ctgWQ6N5g45ReoWpWSXfrgKFc=',
#        'Emma🌺| Reporter👩\u200d💻', 'TRUMP MEDIA NEWS⏺',
#        '▶ TRUMP NEWS DAILY', 'Caroline Walker 🌸', 'Olivia Allen🚂',
#        'Aria Wilson🚂', 'Samantha Clark💕', 'Breaking News🔥',
#        'Lauren4Trump🍒', 'Sophia Evans💗🌴',
#        'MUqZv6hxFW92V7lxJyf35c8BU8esdxS6IoV1QGiwwtQ=', 'Anna🇲 🇦 🇬 🇦 🇺🇸',
#        'Sophia Miller 💙', 'TRUMPTRAIN🚂FakeNews',
#        'TDgi60XrT+ylS+rVJEMhb4Y2qzW2HnZmlijAyHNqavc=',
#        '55DeTN4VJIeKfM9Atr0sSTLomZbJyUWuBNdDK2an1nE=',
#        'Noticias Viral TV', 'Lauren Jones 🇺🇸',
#        'EAMY+7SRc0r53i1vfKV4UvVAc+DAI4rtEpUjFSbwbQ=', '🌹Alyssa Nelson🐸',
#        'Caroline Walker', 'Abby Martin✨', 'Lauren Jones 🇺🇸',
#        'Citizens For Trump🌎'], dtype=object)

# %%
plt.figure(figsize=(20, 12))
ax = plt.subplot()
plt.bar(range(len(venezuela_users)),
        venezuela_users.follower_count)
ax.set_xticks(range(len(venezuela_users.user_screen_name)))
ax.set_xticklabels(venezuela_users.user_screen_name.values,rotation=90,size=20)
plt.ylabel('Number of Followers',size=30)
plt.title('Twitter Handles',size=30)
plt.show()

# %%
venezuela_users.user_display_name.values
# Out:
# array(['AmericaForTrump🇺🇸', 'UaoSsTUDoR7SIA0dvPLYLRt70LG0VUSS3AcrE9FUE=',
#        'Evelyn Reporter👩🏻\u200d💻', 'TRUMP TRAIN🚂💨', '#TrumpNews 🇺🇸',
#        'TrumpservativeNews 🇺🇸', 'TRUMP TRAIN 🚂', '▶ Trump Daily News 📰',
#        '944Ry+vVZhaSln1T9ctgWQ6N5g45ReoWpWSXfrgKFc=',
#        'Emma🌺| Reporter👩\u200d💻', 'TRUMP MEDIA NEWS⏺',
#        '▶ TRUMP NEWS DAILY', 'Caroline Walker 🌸', 'Olivia Allen🚂',
#        'Aria Wilson🚂', 'Samantha Clark💕', 'Breaking News🔥',
#        'Lauren4Trump🍒', 'Sophia Evans💗🌴',
#        'MUqZv6hxFW92V7lxJyf35c8BU8esdxS6IoV1QGiwwtQ=', 'Anna🇲 🇦 🇬 🇦 🇺🇸',
#        'Sophia Miller 💙', 'TRUMPTRAIN🚂FakeNews',
#        'TDgi60XrT+ylS+rVJEMhb4Y2qzW2HnZmlijAyHNqavc=',
#        '55DeTN4VJIeKfM9Atr0sSTLomZbJyUWuBNdDK2an1nE=',
#        'Noticias Viral TV', 'Lauren Jones 🇺🇸',
#        'EAMY+7SRc0r53i1vfKV4UvVAc+DAI4rtEpUjFSbwbQ=', '🌹Alyssa Nelson🐸',
#        'Caroline Walker', 'Abby Martin✨', 'Lauren Jones 🇺🇸',
#        'Citizens For Trump🌎'], dtype=object)

# %% [markdown]
# # Look at all keywords. sort based on frequency, put it together, bag of words, highest frequency. for each tweet remove stop keyword. plot words that arent stop or keyword. find emoji, if you can label emoji. Try to change everything to scatterplot, barchart, histogram, etc.

# %%
user_location = venezuela_users.groupby('user_reported_location').count()['userid']

# %%
user_location
# Out:
# user_reported_location
# Caracas, Venezuela    1
# Florida, USA          2
# New York, NY          1
# Nueva York, USA       5
# Texas, USA            4
# Washington, DC        5
# Name: userid, dtype: int64

# %%
loc_df = venezuela_users[['userid','user_reported_location']]

# %%
loc_df
# Out:
#                                           userid user_reported_location
# 0                             778257194076831744         Washington, DC
# 1     UaoSsTUDoR7SIA0dvPLYLRt70LG0VUSS3AcrE9FUE=         Washington, DC
# 2                             801485278858854401                    NaN
# 3                             881675624401833984                    NaN
# 4                             768237282562310144         Washington, DC
# 5                             801200139155214336                    NaN
# 6                             828668571765133317             Texas, USA
# 7                             801555575687495681                    NaN
# 8    944Ry+vVZhaSln1T9ctgWQ6N5g45ReoWpWSXfrgKFc=     Caracas, Venezuela
# 9                             896121971989262336                    NaN
# 10                            933477319615877120                    NaN
# 11                            801463213833547776                    NaN
# 12                            751635009052827648        Nueva York, USA
# 13                            801609388779769857             Texas, USA
# 14                            751630413769113601           New York, NY
# 15                            801442896041873409             Texas, USA
# 16                            933480574685270017                    NaN
# 17                            892133369965944833                    NaN
# 18                            772513370599747585           Florida, USA
# 19  MUqZv6hxFW92V7lxJyf35c8BU8esdxS6IoV1QGiwwtQ=                    NaN
# 20                            801569072618029056           Florida, USA
# 21                            741112500356276225        Nueva York, USA
# 22                            769380097359024128        Nueva York, USA
# 23  TDgi60XrT+ylS+rVJEMhb4Y2qzW2HnZmlijAyHNqavc=         Washington, DC
# 24  55DeTN4VJIeKfM9Atr0sSTLomZbJyUWuBNdDK2an1nE=                    NaN
# 25                                     568620329                    NaN
# 26                            741092772233482241        Nueva York, USA
# 27   EAMY+7SRc0r53i1vfKV4UvVAc+DAI4rtEpUjFSbwbQ=             Texas, USA
# 28                            801221525718335488                    NaN
# 29                            862552763414323201                    NaN
# 30                            761401522798333952         Washington, DC
# 31                            801544458777063424        Nueva York, USA
# 32                            945770142297939968                    NaN

# %%
user_location = loc_df.groupby('user_reported_location').count()['userid']
user_location
# Out:
# user_reported_location
# Caracas, Venezuela    1
# Florida, USA          2
# New York, NY          1
# Nueva York, USA       5
# Texas, USA            4
# Washington, DC        5
# Name: userid, dtype: int64

# %%
venezuela_users.columns
# Out:
# Index(['userid', 'user_display_name', 'user_screen_name',
#        'user_reported_location', 'user_profile_description',
#        'user_profile_url', 'follower_count', 'following_count',
#        'account_creation_date', 'account_language'],
#       dtype='object')

# %%
plt.figure(figsize=(25,8))
plt.plot(venezuela_users.account_creation_date)
plt.xlabel('YEARS', fontsize = 16)
plt.ylabel('Total No. Tweets', fontsize = 18)
plt.title('Monthly Number of Tweets\n2012 to 2019', fontsize = 16);
